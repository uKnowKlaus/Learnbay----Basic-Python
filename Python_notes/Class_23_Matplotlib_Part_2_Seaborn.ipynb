# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datasets/weather_by_cities_group_by.csv')
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
g = df.groupby(by = 'city')

list(g)
# Out:
# [('mumbai',
#           day    city  temperature  windspeed  event
#   4  1/1/2017  mumbai           90          5  Sunny
#   5  1/2/2017  mumbai           85         12    Fog
#   6  1/3/2017  mumbai           87         15    Fog
#   7  1/4/2017  mumbai           92          5   Rain),
#  ('new york',
#           day      city  temperature  windspeed  event
#   0  1/1/2017  new york           32          6   Rain
#   1  1/2/2017  new york           36          7  Sunny
#   2  1/3/2017  new york           28         12   Snow
#   3  1/4/2017  new york           33          7  Sunny),
#  ('paris',
#            day   city  temperature  windspeed   event
#   8   1/1/2017  paris           45         20   Sunny
#   9   1/2/2017  paris           50         13  Cloudy
#   10  1/3/2017  paris           54          8  Cloudy
#   11  1/4/2017  paris           42         10  Cloudy)]

# %%
g.max()
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
g.get_group('mumbai')
# Out:
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain

# %%
df_new = g.get_group('new york')

# %%
df_new
# Out:
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny

# %%
g.get_group('paris')['event'].mode()
# Out:
# 0    Cloudy
# Name: event, dtype: object

# %% [markdown]
# # bar graph

# %%
company = ['google' , 'fb' , 'msft' , 'amzn']
stock = [323,454,656,324]

# %%
plt.bar(company , stock)
plt.xlabel('companies')
plt.ylabel('Stock prices')
plt.title('Stock information')
# Out:
# Text(0.5, 1.0, 'Stock information')

# %%
plt.barh(company , stock)
plt.ylabel('companies')
plt.xlabel('Stock prices')
plt.title('Stock information')
# Out:
# Text(0.5, 1.0, 'Stock information')

# %% [markdown]
# # Histogram

# %%
blood_sugar = [113,85,100,90,150,149,88,93,115, 80,77,81,129]


# 80 - 100 ---> normal 
# 100 - 125 --> pre diabetic
# 125 --> diabetic

# %%
plt.hist(blood_sugar) # by default the bins = 10
# Out:
# (array([3., 3., 1., 1., 1., 1., 0., 1., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
blood_sugar = [113,85,100,90,150,149,88,93,115, 80,77,81,129, 149]
plt.hist(blood_sugar , bins = [77,100,125,150]) # by default the bins = 10

# 80 - 100 ---> normal 
# 100 - 125 --> pre diabetic
# 125 --> diabetic
# Out:
# (array([7., 3., 4.]),
#  array([ 77, 100, 125, 150]),
#  <BarContainer object of 3 artists>)

# %%
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]


plt.hist([blood_sugar_men , blood_sugar_women] , bins = [77,100,125,150] , color = ['green' , 'orange'] ,
        label = ['MEN' , 'WOMEN'])

plt.legend()

# %%
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129 , 120]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100 , 101]


plt.hist([blood_sugar_men , blood_sugar_women] , bins = [77,100,125,150] , color = ['green' , 'orange'] ,
        label = ['MEN' , 'WOMEN'])

plt.legend()

# %%
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129 , 120]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100 , 101]


plt.hist([blood_sugar_men , blood_sugar_women] , bins = [67,100,125,150] , color = ['green' , 'orange'] ,
        label = ['MEN' , 'WOMEN'])

plt.legend()

# %%
# Creating dataset
marks = np.array([70, 50, 40, 90, 55, 85, 74, 66, 33, 11, 45, 36, 89])

# Creating histogram
fig, ax = plt.subplots(1, 1)
ax.hist(marks)

# Set title
ax.set_title("Title")

# adding labels
ax.set_xlabel('x-label')
ax.set_ylabel('y-label')

# Make some labels.
rects = ax.patches
labels = ["label%d" % i for i in range(len(rects))]

for rect, label in zip(rects, labels):
	height = rect.get_height()
	ax.text(rect.get_x() + rect.get_width() / 2, height+0.01, label,
			ha='center', va='bottom')

# Show plot
plt.show()

# %% [markdown]
# # Pie

# %%
exp_values = [1500, 600 , 300 , 500 , 450] 

plt.pie(exp_values)
plt.show()

# %%
exp_values = [1500, 600 , 300 , 350 , 450] 
exp_labels = ['Rent' , 'Food' , 'Internet' ,'Car' , 'other_utilities']

plt.pie(exp_values , labels= exp_labels)
plt.show()

# %%
exp_values = [1500, 600 , 300 , 350 , 450] 
exp_labels = ['Rent' , 'Food' , 'Internet' ,'Car' , 'other_utilities']

plt.pie(exp_values , labels= exp_labels , radius = 3)
plt.show()

# %%
exp_values = [1500, 600 , 300 , 350 , 450] 
exp_labels = ['Rent' , 'Food' , 'Internet' ,'Car' , 'other_utilities']

plt.pie(exp_values , labels= exp_labels , radius = 2 , autopct = '%0.02f%%')
plt.show()

# %%
exp_values = [1500, 600 , 300 , 350 , 450] 
exp_labels = ['Rent' , 'Food' , 'Internet' ,'Car' , 'other_utilities']

plt.pie(exp_values , labels= exp_labels , radius = 2 , autopct = '%0.03f%%')
plt.show()

# %%
exp_values = [1500, 600 , 300 , 350 , 450] 
exp_labels = ['Rent' , 'Food' , 'Internet' ,'Car' , 'other_utilities']

plt.pie(exp_values , labels= exp_labels , radius = 2 , autopct = '%0.03f%%' , explode = [0,0.2,0,0,0.5])
plt.show()

# %% [markdown]
# # Scatter plot

# %%
df_mumbai = df.groupby('city').get_group('mumbai')
df_mumbai
# Out:
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain

# %%
plt.scatter(x = df_mumbai['temperature']  , y = df_mumbai['windspeed'])

# %%
x = [1,2,3,4,5,6,7]
y = [122,134,455,567,766,854,900]


plt.scatter(x,y)

# %% [markdown]
# # SUBPLOT

# %%
plt.figure(figsize=(20,10))

plt.subplot(3,3,1)

x = [1,2,3,4,5,6,7]
y = [122,134,455,567,766,854,900]


plt.scatter(x,y)


plt.subplot(3,3,5)
exp_values = [1500, 600 , 300 , 350 , 450] 
exp_labels = ['Rent' , 'Food' , 'Internet' ,'Car' , 'other_utilities']

plt.pie(exp_values , labels= exp_labels , radius = 2 , autopct = '%0.03f%%' , explode = [0,0.2,0,0,0.5])
plt.show()

plt.subplot(3,3,9)

plt.hist([blood_sugar_men , blood_sugar_women] , bins = [67,100,125,150] , color = ['green' , 'orange'] ,
        label = ['MEN' , 'WOMEN'])

plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,3,1)

x = [1,2,3,4,5,6,7]
y = [122,134,455,567,766,854,900]


plt.scatter(x,y)


plt.subplot(2,3,2)
plt.scatter(x,y)


plt.subplot(2,3,6)
plt.scatter(x,y)

# %%
x = [1,2,3,4,5,6,7]
y = [122,134,455,567,766,854,900]


plt.scatter(x,y)
plt.savefig('datasets/image.jpg')

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
print(df['day'].unique())
print(df['time'].unique())
print(df['size'].unique())
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']
# [2 3 4 1 6 5]

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = 'total_bill' , y = 'tip' , data = df)

# %%
sns.relplot(x = 'total_bill' , y = 'tip' ,hue= 'smoker', data = df)

# %%
sns.relplot(x = 'total_bill' , y = 'tip' ,hue= 'smoker', size = 'day',data = df)

# %%
sns.relplot(x = 'total_bill' , y = 'tip' ,hue= 'smoker', size = 'time',data = df)

# %%
sns.relplot(x = 'total_bill' , y = 'tip' ,hue= 'smoker', size = 'time',style = 'day',data = df)

# %%
sns.relplot(x = 'total_bill' , y = 'tip' ,hue = 'sex',data = df)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = 'total_bill' , y = 'tip' ,col = 'sex',data = df)

# %%
sns.relplot(x = 'total_bill' , y = 'tip' ,col = 'time',data = df)

# %%
sns.relplot(x = 'total_bill' , y = 'tip' ,col = 'smoker',data = df)

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.scatter(x = 'sepal_length' , y = 'sepal_width' , data = df)

# %%
sns.scatterplot(x = 'sepal_length' , y = 'sepal_width' , data = df)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x = 'day' , y = 'total_bill' , data = df)

# %%
sns.catplot(x = 'day' , y = 'total_bill' , data = df , jitter = False)

# %%
sns.catplot(x = 'day' , y = 'total_bill' , data = df , kind = 'swarm')

# %%
sns.catplot(x = 'day' , y = 'total_bill' , data = df , kind = 'box')

# %%
sns.catplot(x = 'day' , y = 'total_bill' , data = df , kind = 'violin')

# %% [markdown]
# # Displot

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(x = 'total_bill' , data = df)

# %%
sns.displot(x = 'total_bill' , data = df , kde = True)

# %%
sns.displot(x = 'total_bill' , data = df ,kind = 'kde' )

# %%
sns.displot(x = 'total_bill' , data = df ,kind = 'ecdf' )

# %%
sns.pairplot(df)

# %%
# 

df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
